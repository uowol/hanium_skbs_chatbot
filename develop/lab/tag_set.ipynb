# %%
import pandas as pd

# %%
csv_file = pd.read_csv('C:/Users/user/Documents/카카오톡 받은 파일/tag.csv')

# %%
for i in set(csv_file['태그']):
    print('"' + i.replace('/', ',') + '","' + i.replace('/', ',') + '","' + i.replace('/', ',') + '여행","' + i.replace('/', ',') + ' 여행"')
# Out:
# "박물관","박물관","박물관여행","박물관 여행"
# "촬영지","촬영지","촬영지여행","촬영지 여행"
# "수목원,휴양림","수목원,휴양림","수목원,휴양림여행","수목원,휴양림 여행"
# "스쿠버다이빙","스쿠버다이빙","스쿠버다이빙여행","스쿠버다이빙 여행"
# "시장","시장","시장여행","시장 여행"
# "공방","공방","공방여행","공방 여행"
# "골프","골프","골프여행","골프 여행"
# "극장","극장","극장여행","극장 여행"
# "기타 전시시설","기타 전시시설","기타 전시시설여행","기타 전시시설 여행"
# "과학관","과학관","과학관여행","과학관 여행"
# "교육시설","교육시설","교육시설여행","교육시설 여행"
# "계곡","계곡","계곡여행","계곡 여행"
# "바다","바다","바다여행","바다 여행"
# "기타_하천,해양","기타_하천,해양","기타_하천,해양여행","기타_하천,해양 여행"
# "농어촌체험","농어촌체험","농어촌체험여행","농어촌체험 여행"
# "아트홀","아트홀","아트홀여행","아트홀 여행"
# "등산","등산","등산여행","등산 여행"
# "야구","야구","야구여행","야구 여행"
# "늪","늪","늪여행","늪 여행"
# "역사유적지","역사유적지","역사유적지여행","역사유적지 여행"
# "동계스포츠","동계스포츠","동계스포츠여행","동계스포츠 여행"
# "호수","호수","호수여행","호수 여행"
# "수상레포츠","수상레포츠","수상레포츠여행","수상레포츠 여행"
# "기타육상스포츠","기타육상스포츠","기타육상스포츠여행","기타육상스포츠 여행"
# "유교","유교","유교여행","유교 여행"
# "서핑","서핑","서핑여행","서핑 여행"
# "문화센터","문화센터","문화센터여행","문화센터 여행"
# "불교","불교","불교여행","불교 여행"
# "낚시","낚시","낚시여행","낚시 여행"
# "데이트","데이트","데이트여행","데이트 여행"
# ...
